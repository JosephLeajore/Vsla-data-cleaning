# %%
import pandas as pd
df = pd.read_csv(r"D:\Semester 4\Revised Thesis\Thesis Survey.csv")
df.head()
# Out:
#                   Zeitstempel 1.     What is your gender?  \
# 0   2025/03/19 1:09:56 PM MEZ                        Male
# 1   2025/03/19 1:55:19 PM MEZ                        Male
# 2   2025/03/19 6:14:34 PM MEZ                      Female
# 3   2025/03/19 9:31:11 PM MEZ                        Male
# 4  2025/03/19 10:30:44 PM MEZ                        Male
#
#   2. In which age group do you belong?  \
# 0                                26-35
# 1                                26-35
# 2                                26-35
# 3                                18-25
# 4                                26-35
#
#   3. What is your highest education level?  \
# 0              College/University and more
# 1              College/University and more
# 2              College/University and more
# 3                      Secondary education
# 4              College/University and more
#
#   4. For how long are you a member of a Village Saving and Loan Association (VSLA)?  \
# ...

# %%
df=df.drop(columns=['Zeitstempel'], errors='ignore')
df.dropna()
df.head()
# Out:
#   1.     What is your gender? 2. In which age group do you belong?  \
# 0                        Male                                26-35
# 1                        Male                                26-35
# 2                      Female                                26-35
# 3                        Male                                18-25
# 4                        Male                                26-35
#
#   3. What is your highest education level?  \
# 0              College/University and more
# 1              College/University and more
# 2              College/University and more
# 3                      Secondary education
# 4              College/University and more
#
#   4. For how long are you a member of a Village Saving and Loan Association (VSLA)?  \
# 0                                   Less than 1 year
# 1                                          1-3 years
# 2                                          1-3 years
# ...

# %%
df=df.drop(columns=['15. Give your suggestions of what you think is the impact of use of alternative money to businesses owned by Village Saving and Loan Association (VSLA) members.'],errors='ignore')
df.dropna()
df.head()
# Out:
#   1.     What is your gender? 2. In which age group do you belong?  \
# 0                        Male                                26-35
# 1                        Male                                26-35
# 2                      Female                                26-35
# 3                        Male                                18-25
# 4                        Male                                26-35
#
#   3. What is your highest education level?  \
# 0              College/University and more
# 1              College/University and more
# 2              College/University and more
# 3                      Secondary education
# 4              College/University and more
#
#   4. For how long are you a member of a Village Saving and Loan Association (VSLA)?  \
# 0                                   Less than 1 year
# 1                                          1-3 years
# 2                                          1-3 years
# ...

# %%
df=df.drop(columns=['16. What is your recommendation to improve trade between your Village Saving and Loan Association (VSLA) members and other neighbouring VSLA groups?'], errors='ignore')
df.dropna()
df.head()
# Out:
#   1.     What is your gender? 2. In which age group do you belong?  \
# 0                        Male                                26-35
# 1                        Male                                26-35
# 2                      Female                                26-35
# 3                        Male                                18-25
# 4                        Male                                26-35
#
#   3. What is your highest education level?  \
# 0              College/University and more
# 1              College/University and more
# 2              College/University and more
# 3                      Secondary education
# 4              College/University and more
#
#   4. For how long are you a member of a Village Saving and Loan Association (VSLA)?  \
# 0                                   Less than 1 year
# 1                                          1-3 years
# 2                                          1-3 years
# ...

# %%
df.rename(columns={
    '1.     What is your gender?':'gender','2. In which age group do you belong?':'age','3. What is your highest education level?':'education'
},inplace=True)
df.head()
# Out:
#    gender    age                    education  \
# 0    Male  26-35  College/University and more
# 1    Male  26-35  College/University and more
# 2  Female  26-35  College/University and more
# 3    Male  18-25          Secondary education
# 4    Male  26-35  College/University and more
#
#   4. For how long are you a member of a Village Saving and Loan Association (VSLA)?  \
# 0                                   Less than 1 year
# 1                                          1-3 years
# 2                                          1-3 years
# 3                                          1-3 years
# 4                                          4-6 years
#
#   5. What type of business do you operate?  \
# 0                          Other (Specify)
# 1                     Not a Business Owner
# 2                          Other (Specify)
# 3                                   Retail
# 4                                 Hardware
#
# ...

# %%
df.rename(columns=
           {'1.     What is your gender?':'gender','2. In which age group do you belong?':'age','3. What is your highest education level?':'education','4. For how long are you a member of a Village Saving and Loan Association (VSLA)?':'vsla_membership','5. What type of business do you operate?':'business type','6. How dependent is your business to credit from Village Saving and Loan Association (VSLA) to grow? (1=Not at all Dependent and 4 = Very Dependent)':'vsla_dependency',
'7. Generally, how satisfied are you with loans offered by VSLA? (1= Very Dissatisfied and 4 Very Satisfied)':'loan_satisfaction',
 '8. How satisfied are you with the capacity of Village Savings and Loans Association (VSLAs) to offer the following services? [Savings]':'vsla_loan_capacity','8. How satisfied are you with the capacity of Village Savings and Loans Association (VSLAs) to offer the following services? [Savings]':'saving',
                 '8. How satisfied are you with the capacity of Village Savings and Loans Association (VSLAs) to offer the following services? [Loans]':'loan','8. How satisfied are you with the capacity of Village Savings and Loans Association (VSLAs) to offer the following services? [Financial Training]':'financial_training',
                  '8. How satisfied are you with the capacity of Village Savings and Loans Association (VSLAs) to offer the following services? [Emergency Loan]':'emergency_loan',
                  '9. How often do you trade with businesses owned by other Village Saving and Loan Association (VSLA) members? (1=Rarely and 4= Always)': 'memmbers_trading', 
                   '10. How likely are you to trade with members of other Village Saving and Loan Association (VSLA) groups other than your own group? (1= Very Unlikely and 4=Very likely)': 'intergroup_trade', 
                   '11. How satisfied are you with your VSLA group creating a business network with other existing VSLA groups to grow your own business? (1= Very Unsatisfied and 4= Very Satisfied)':'vsa_business_network', 
                   '12. How likely is it for you to use another currency other than the Nation currency to trade? For example, use of Vouchers. (1=Very unlikely and 5 =Very Likely)':'alt_currency',
                   '13. To what extent do you agree to the use of an alternative payment currency other than the national currency in Village Saving and Loan Association (VSLA)? (1= Strongly Disagree and 4 = Strongly Agree)':'alt_agreement',
                   '14. Overall, how likely is the use of an alternative money affect positively the following in relation to your business as Village Saving and Loan Association (VSLA) member? [Increase access to credit]':'alt_impact_credit',
                   '14. Overall, how likely is the use of an alternative money affect positively the following in relation to your business as Village Saving and Loan Association (VSLA) member? [ Increase business growth]':'alt_businessgrowth',
                   '14. Overall, how likely is the use of an alternative money affect positively the following in relation to your business as Village Saving and Loan Association (VSLA) member? [Increase in trading activities among members]':'alt_tradepromotion'
           },inplace=True)
df.head()
# Out:
#    gender    age                    education   vsla_membership  \
# 0    Male  26-35  College/University and more  Less than 1 year
# 1    Male  26-35  College/University and more         1-3 years
# 2  Female  26-35  College/University and more         1-3 years
# 3    Male  18-25          Secondary education         1-3 years
# 4    Male  26-35  College/University and more         4-6 years
#
#           business type       vsla_dependency loan_satisfaction  \
# 0       Other (Specify)  Not at all dependent      Dissatisfied
# 1  Not a Business Owner    Somewhat Dependent         Satisfied
# 2       Other (Specify)  Not at all dependent         Satisfied
# 3                Retail        Very Dependent    Very Satisfied
# 4              Hardware        Very Dependent      Dissatisfied
#
#               saving               loan financial_training     emergency_loan  \
# 0       Dissatisfied       Dissatisfied       Dissatisfied       Dissatisfied
# ...

# %%
print(df['gender'].unique())
# Out:
# ['Male' 'Female' 'I prefer not to say']

# %%
df['gender'] = df['gender'].map({'Male': 1,'Female': 2, 'I prefer not to say': 0 })
df.head()
# Out:
#    gender    age                    education   vsla_membership  \
# 0       1  26-35  College/University and more  Less than 1 year
# 1       1  26-35  College/University and more         1-3 years
# 2       2  26-35  College/University and more         1-3 years
# 3       1  18-25          Secondary education         1-3 years
# 4       1  26-35  College/University and more         4-6 years
#
#           business type       vsla_dependency loan_satisfaction  \
# 0       Other (Specify)  Not at all dependent      Dissatisfied
# 1  Not a Business Owner    Somewhat Dependent         Satisfied
# 2       Other (Specify)  Not at all dependent         Satisfied
# 3                Retail        Very Dependent    Very Satisfied
# 4              Hardware        Very Dependent      Dissatisfied
#
#               saving               loan financial_training     emergency_loan  \
# 0       Dissatisfied       Dissatisfied       Dissatisfied       Dissatisfied
# ...

# %%
print(df['education'].unique())
# Out:
# ['College/University and more' 'Secondary education' 'Primary education'
#  'No formal education']

# %%
df['education'] = df['education'].map({'College/University and more': 4,'Secondary education': 3,'Primary education': 2,'No formal education': 1 })
df.head()
# Out:
#    gender    age  education   vsla_membership         business type  \
# 0       1  26-35          4  Less than 1 year       Other (Specify)
# 1       1  26-35          4         1-3 years  Not a Business Owner
# 2       2  26-35          4         1-3 years       Other (Specify)
# 3       1  18-25          3         1-3 years                Retail
# 4       1  26-35          4         4-6 years              Hardware
#
#         vsla_dependency loan_satisfaction             saving  \
# 0  Not at all dependent      Dissatisfied       Dissatisfied
# 1    Somewhat Dependent         Satisfied          Satisfied
# 2  Not at all dependent         Satisfied  Very Dissatisfied
# 3        Very Dependent    Very Satisfied     Very Satisfied
# 4        Very Dependent      Dissatisfied          Satisfied
#
#                 loan financial_training     emergency_loan memmbers_trading  \
# 0       Dissatisfied       Dissatisfied       Dissatisfied           Rarely
# ...

# %%
print(df['vsla_membership'].unique())
# Out:
# ['Less than 1 year' '1-3 years' '4-6 years' 'More than 6 years']

# %%
df['vsla_membership'] = df['vsla_membership'].map({'Less than 1 year': 1,'1-3 years': 2, '4-6 years': 3, 'More than 6 years': 4})
df.head()
# Out:
#    gender    age  education  vsla_membership         business type  \
# 0       1  26-35          4                1       Other (Specify)
# 1       1  26-35          4                2  Not a Business Owner
# 2       2  26-35          4                2       Other (Specify)
# 3       1  18-25          3                2                Retail
# 4       1  26-35          4                3              Hardware
#
#         vsla_dependency loan_satisfaction             saving  \
# 0  Not at all dependent      Dissatisfied       Dissatisfied
# 1    Somewhat Dependent         Satisfied          Satisfied
# 2  Not at all dependent         Satisfied  Very Dissatisfied
# 3        Very Dependent    Very Satisfied     Very Satisfied
# 4        Very Dependent      Dissatisfied          Satisfied
#
#                 loan financial_training     emergency_loan memmbers_trading  \
# 0       Dissatisfied       Dissatisfied       Dissatisfied           Rarely
# ...

# %%
print(df['age'].unique())
# Out:
# ['26-35' '18-25' '46-55' '36-45']

# %%
df['age'] = df['age'].map({'26-35': 2, '18-25': 1, '46-55': 4, '36-45': 3})
df.head()
# Out:
#    gender  age  education  vsla_membership         business type  \
# 0       1    2          4                1       Other (Specify)
# 1       1    2          4                2  Not a Business Owner
# 2       2    2          4                2       Other (Specify)
# 3       1    1          3                2                Retail
# 4       1    2          4                3              Hardware
#
#         vsla_dependency loan_satisfaction             saving  \
# 0  Not at all dependent      Dissatisfied       Dissatisfied
# 1    Somewhat Dependent         Satisfied          Satisfied
# 2  Not at all dependent         Satisfied  Very Dissatisfied
# 3        Very Dependent    Very Satisfied     Very Satisfied
# 4        Very Dependent      Dissatisfied          Satisfied
#
#                 loan financial_training     emergency_loan memmbers_trading  \
# 0       Dissatisfied       Dissatisfied       Dissatisfied           Rarely
# ...

# %%
print(df['business type'].unique())
# Out:
# ['Other (Specify)' 'Not a Business Owner' 'Retail' 'Hardware'
#  'Service (e.g. hotel, Mpesa etc.)' 'Wholesale']

# %%
df['business type'] = df['business type'].map({'Other (Specify)':6, 'Not a Business Owner': 5, 'Retail': 1, 'Hardware': 3, 'Service (e.g. hotel, Mpesa etc.)':2, 'Wholesale': 4})
df.head()
# Out:
#    gender  age  education  vsla_membership  business type  \
# 0       1    2          4                1              6
# 1       1    2          4                2              5
# 2       2    2          4                2              6
# 3       1    1          3                2              1
# 4       1    2          4                3              3
#
#         vsla_dependency loan_satisfaction             saving  \
# 0  Not at all dependent      Dissatisfied       Dissatisfied
# 1    Somewhat Dependent         Satisfied          Satisfied
# 2  Not at all dependent         Satisfied  Very Dissatisfied
# 3        Very Dependent    Very Satisfied     Very Satisfied
# 4        Very Dependent      Dissatisfied          Satisfied
#
#                 loan financial_training     emergency_loan memmbers_trading  \
# 0       Dissatisfied       Dissatisfied       Dissatisfied           Rarely
# 1       Dissatisfied          Satisfied  Very Dissatisfied        Sometimes
# ...

# %%
print(df['vsla_dependency'].unique())
# Out:
# ['Not at all dependent' 'Somewhat Dependent' 'Very Dependent'
#  'A little Dependent']

# %%
df['vsla_dependency'] = df['vsla_dependency'].map({'Not at all dependent': 1, 'Somewhat Dependent': 3, 'Very Dependent': 4, 'A little Dependent': 2})
df.head()
# Out:
#    gender  age  education  vsla_membership  business type  vsla_dependency  \
# 0       1    2          4                1              6                1
# 1       1    2          4                2              5                3
# 2       2    2          4                2              6                1
# 3       1    1          3                2              1                4
# 4       1    2          4                3              3                4
#
#   loan_satisfaction             saving               loan financial_training  \
# 0      Dissatisfied       Dissatisfied       Dissatisfied       Dissatisfied
# 1         Satisfied          Satisfied       Dissatisfied          Satisfied
# 2         Satisfied  Very Dissatisfied  Very Dissatisfied  Very Dissatisfied
# 3    Very Satisfied     Very Satisfied     Very Satisfied     Very Satisfied
# 4      Dissatisfied          Satisfied  Very Dissatisfied          Satisfied
#
# ...

# %%
print(df['loan_satisfaction'].unique())
# Out:
# ['Dissatisfied' 'Satisfied' 'Very Satisfied' 'Very Dissatisfied']

# %%
df['loan_satisfaction'] = df['loan_satisfaction'].map({'Dissatisfied': 1, 'Satisfied': 2, 'Very Satisfied': 3, 'Very Dissatisfied': 4})
df.head()
# Out:
#    gender  age  education  vsla_membership  business type  vsla_dependency  \
# 0       1    2          4                1              6                1
# 1       1    2          4                2              5                3
# 2       2    2          4                2              6                1
# 3       1    1          3                2              1                4
# 4       1    2          4                3              3                4
#
#    loan_satisfaction             saving               loan financial_training  \
# 0                  1       Dissatisfied       Dissatisfied       Dissatisfied
# 1                  2          Satisfied       Dissatisfied          Satisfied
# 2                  2  Very Dissatisfied  Very Dissatisfied  Very Dissatisfied
# 3                  3     Very Satisfied     Very Satisfied     Very Satisfied
# 4                  1          Satisfied  Very Dissatisfied          Satisfied
#
# ...

# %%
print(df['saving'].unique())
# Out:
# ['Dissatisfied' 'Satisfied' 'Very Dissatisfied' 'Very Satisfied'
#  'Satisfied;Very Satisfied' 'Very Dissatisfied;Dissatisfied'
#  'Very Dissatisfied;Dissatisfied;Satisfied'
#  'Very Dissatisfied;Very Satisfied']

# %%
df['saving'] = df['saving'].map({'Dissatisfied': 1, 'Satisfied': 2, 'Very Dissatisfied': 3, 'Very Satisfied': 4,})
df.head()
# Out:
#    gender  age  education  vsla_membership  business type  vsla_dependency  \
# 0       1    2          4                1              6                1
# 1       1    2          4                2              5                3
# 2       2    2          4                2              6                1
# 3       1    1          3                2              1                4
# 4       1    2          4                3              3                4
#
#    loan_satisfaction  saving               loan financial_training  \
# 0                  1     1.0       Dissatisfied       Dissatisfied
# 1                  2     2.0       Dissatisfied          Satisfied
# 2                  2     3.0  Very Dissatisfied  Very Dissatisfied
# 3                  3     4.0     Very Satisfied     Very Satisfied
# 4                  1     2.0  Very Dissatisfied          Satisfied
#
#       emergency_loan memmbers_trading intergroup_trade vsa_business_network  \
# ...

# %%
print(df['loan'].unique())
# Out:
# ['Dissatisfied' 'Very Dissatisfied' 'Very Satisfied' 'Satisfied'
#  'Very Dissatisfied;Dissatisfied'
#  'Very Dissatisfied;Satisfied;Very Satisfied' 'Satisfied;Very Satisfied'
#  'Very Dissatisfied;Satisfied' 'Dissatisfied;Very Satisfied'
#  'Very Dissatisfied;Very Satisfied']

# %%
df['loan'] = df['loan'].map({'Dissatisfied': 2, 'Very Dissatisfied': 1, 'Very Satisfied': 4, 'Satisfied':3})
df.head()
# Out:
#    gender  age  education  vsla_membership  business type  vsla_dependency  \
# 0       1    2          4                1              6                1
# 1       1    2          4                2              5                3
# 2       2    2          4                2              6                1
# 3       1    1          3                2              1                4
# 4       1    2          4                3              3                4
#
#    loan_satisfaction  saving  loan financial_training     emergency_loan  \
# 0                  1     1.0   2.0       Dissatisfied       Dissatisfied
# 1                  2     2.0   2.0          Satisfied  Very Dissatisfied
# 2                  2     3.0   1.0  Very Dissatisfied  Very Dissatisfied
# 3                  3     4.0   4.0     Very Satisfied     Very Satisfied
# 4                  1     2.0   1.0          Satisfied  Very Dissatisfied
#
#   memmbers_trading intergroup_trade vsa_business_network   alt_currency  \
# ...

# %%
print(df['financial_training'].unique())
# Out:
# ['Dissatisfied' 'Satisfied' 'Very Dissatisfied' 'Very Satisfied'
#  'Very Dissatisfied;Satisfied' 'Very Dissatisfied;Dissatisfied'
#  'Very Dissatisfied;Very Satisfied']

# %%
df['financial_training'] = df['financial_training'].map({'Dissatisfied': 2,'Satisfied': 3, 'Very Dissatisfied': 1, 'Very Satisfied': 4})
df.head()
# Out:
#    gender  age  education  vsla_membership  business type  vsla_dependency  \
# 0       1    2          4                1              6                1
# 1       1    2          4                2              5                3
# 2       2    2          4                2              6                1
# 3       1    1          3                2              1                4
# 4       1    2          4                3              3                4
#
#    loan_satisfaction  saving  loan  financial_training     emergency_loan  \
# 0                  1     1.0   2.0                 2.0       Dissatisfied
# 1                  2     2.0   2.0                 3.0  Very Dissatisfied
# 2                  2     3.0   1.0                 1.0  Very Dissatisfied
# 3                  3     4.0   4.0                 4.0     Very Satisfied
# 4                  1     2.0   1.0                 3.0  Very Dissatisfied
#
# ...

# %%
print(df['emergency_loan'].unique())
# Out:
# ['Dissatisfied' 'Very Dissatisfied' 'Very Satisfied' 'Satisfied'
#  'Dissatisfied;Satisfied' 'Very Dissatisfied;Dissatisfied'
#  'Satisfied;Very Satisfied']

# %%
df['emergency_loan'] = df['emergency_loan'].map({'Dissatisfied': 2, 'Very Dissatisfied': 1, 'Very Satisfied': 4, 'Satisfied':3})
df.head()
# Out:
#    gender  age  education  vsla_membership  business type  vsla_dependency  \
# 0       1    2          4                1              6                1
# 1       1    2          4                2              5                3
# 2       2    2          4                2              6                1
# 3       1    1          3                2              1                4
# 4       1    2          4                3              3                4
#
#    loan_satisfaction  saving  loan  financial_training  emergency_loan  \
# 0                  1     1.0   2.0                 2.0             2.0
# 1                  2     2.0   2.0                 3.0             1.0
# 2                  2     3.0   1.0                 1.0             1.0
# 3                  3     4.0   4.0                 4.0             4.0
# 4                  1     2.0   1.0                 3.0             1.0
#
#   memmbers_trading intergroup_trade vsa_business_network   alt_currency  \
# ...

# %%
print(df['memmbers_trading'].unique())
# Out:
# ['Rarely' 'Sometimes' 'Always' 'Often']

# %%
df['memmbers_trading'] = df['memmbers_trading'].map({'Rarely': 1, 'Sometimes': 2, 'Always': 3, 'Often': 4})
df.head()
# Out:
#    gender  age  education  vsla_membership  business type  vsla_dependency  \
# 0       1    2          4                1              6                1
# 1       1    2          4                2              5                3
# 2       2    2          4                2              6                1
# 3       1    1          3                2              1                4
# 4       1    2          4                3              3                4
#
#    loan_satisfaction  saving  loan  financial_training  emergency_loan  \
# 0                  1     1.0   2.0                 2.0             2.0
# 1                  2     2.0   2.0                 3.0             1.0
# 2                  2     3.0   1.0                 1.0             1.0
# 3                  3     4.0   4.0                 4.0             4.0
# 4                  1     2.0   1.0                 3.0             1.0
#
#    memmbers_trading intergroup_trade vsa_business_network   alt_currency  \
# ...

# %%
print(df['intergroup_trade'].unique())
# Out:
# ['Unlikely' 'Very Unlikely' 'Likely' 'Very likely']

# %%
df['intergroup_trade'] = df['intergroup_trade'].map({'Unlikely': 2, 'Very Unlikely': 1, 'Likely': 3, 'Very likely': 4})
df.head()
# Out:
#    gender  age  education  vsla_membership  business type  vsla_dependency  \
# 0       1    2          4                1              6                1
# 1       1    2          4                2              5                3
# 2       2    2          4                2              6                1
# 3       1    1          3                2              1                4
# 4       1    2          4                3              3                4
#
#    loan_satisfaction  saving  loan  financial_training  emergency_loan  \
# 0                  1     1.0   2.0                 2.0             2.0
# 1                  2     2.0   2.0                 3.0             1.0
# 2                  2     3.0   1.0                 1.0             1.0
# 3                  3     4.0   4.0                 4.0             4.0
# 4                  1     2.0   1.0                 3.0             1.0
#
#    memmbers_trading  intergroup_trade vsa_business_network   alt_currency  \
# ...

# %%
print(df['vsa_business_network'].unique())
# Out:
# ['Unsatisfied' 'Satisfied' 'Very Satisfied' 'Very Unsatisfied']

# %%
df['vsa_business_network'] = df['vsa_business_network'].map({'Unsatisfied': 2, 'Satisfied': 3, 'Very Satisfied': 4, 'Very Unsatisfied': 1})
df.head()
# Out:
#    gender  age  education  vsla_membership  business type  vsla_dependency  \
# 0       1    2          4                1              6                1
# 1       1    2          4                2              5                3
# 2       2    2          4                2              6                1
# 3       1    1          3                2              1                4
# 4       1    2          4                3              3                4
#
#    loan_satisfaction  saving  loan  financial_training  emergency_loan  \
# 0                  1     1.0   2.0                 2.0             2.0
# 1                  2     2.0   2.0                 3.0             1.0
# 2                  2     3.0   1.0                 1.0             1.0
# 3                  3     4.0   4.0                 4.0             4.0
# 4                  1     2.0   1.0                 3.0             1.0
#
#    memmbers_trading  intergroup_trade  vsa_business_network   alt_currency  \
# ...

# %%
print(df['alt_currency'].unique())
# Out:
# ['Very Unlikely' 'Likely' 'Very likely' 'Unlikely']

# %%
df['alt_currency'] = df['alt_currency'].map({'Very Unlikely': 1, 'Likely': 3, 'Very likely': 4, 'Unlikely': 2})
df.head()
# Out:
#    gender  age  education  vsla_membership  business type  vsla_dependency  \
# 0       1    2          4                1              6                1
# 1       1    2          4                2              5                3
# 2       2    2          4                2              6                1
# 3       1    1          3                2              1                4
# 4       1    2          4                3              3                4
#
#    loan_satisfaction  saving  loan  financial_training  emergency_loan  \
# 0                  1     1.0   2.0                 2.0             2.0
# 1                  2     2.0   2.0                 3.0             1.0
# 2                  2     3.0   1.0                 1.0             1.0
# 3                  3     4.0   4.0                 4.0             4.0
# 4                  1     2.0   1.0                 3.0             1.0
#
#    memmbers_trading  intergroup_trade  vsa_business_network  alt_currency  \
# ...

# %%
print(df['alt_agreement'].unique())
# Out:
# ['Disagree' 'Agree' 'Strongly Agree' 'Strongly Disagree']

# %%
df['alt_agreement'] = df['alt_agreement'].map({'Disagree': 2, 'Agree': 3, 'Strongly Agree': 4, 'Strongly Disagree': 1})
df.head()
# Out:
#    gender  age  education  vsla_membership  business type  vsla_dependency  \
# 0       1    2          4                1              6                1
# 1       1    2          4                2              5                3
# 2       2    2          4                2              6                1
# 3       1    1          3                2              1                4
# 4       1    2          4                3              3                4
#
#    loan_satisfaction  saving  loan  financial_training  emergency_loan  \
# 0                  1     1.0   2.0                 2.0             2.0
# 1                  2     2.0   2.0                 3.0             1.0
# 2                  2     3.0   1.0                 1.0             1.0
# 3                  3     4.0   4.0                 4.0             4.0
# 4                  1     2.0   1.0                 3.0             1.0
#
#    memmbers_trading  intergroup_trade  vsa_business_network  alt_currency  \
# ...

# %%
print(df['alt_impact_credit'].unique())
# Out:
# ['Unlikely' 'Very likely' 'likely' 'Unlikely;likely' 'Very unlikely'
#  'Very unlikely;Unlikely;likely;Very likely' 'likely;Very likely'
#  'Very unlikely;Very likely']

# %%
df['alt_impact_credit'] = df['alt_impact_credit'].map({'Unlikely': 2, 'Very likely': 4, 'likely': 3, 'Very unlikely': 1 })
df.head()
# Out:
#    gender  age  education  vsla_membership  business type  vsla_dependency  \
# 0       1    2          4                1              6                1
# 1       1    2          4                2              5                3
# 2       2    2          4                2              6                1
# 3       1    1          3                2              1                4
# 4       1    2          4                3              3                4
#
#    loan_satisfaction  saving  loan  financial_training  emergency_loan  \
# 0                  1     1.0   2.0                 2.0             2.0
# 1                  2     2.0   2.0                 3.0             1.0
# 2                  2     3.0   1.0                 1.0             1.0
# 3                  3     4.0   4.0                 4.0             4.0
# 4                  1     2.0   1.0                 3.0             1.0
#
#    memmbers_trading  intergroup_trade  vsa_business_network  alt_currency  \
# ...

# %%
print(df['alt_businessgrowth'].unique())
# Out:
# ['Unlikely' 'Very likely' 'likely'
#  'Very unlikely;Unlikely;likely;Very likely' 'Very unlikely'
#  'Very unlikely;Unlikely' 'Very unlikely;Very likely']

# %%
df['alt_businessgrowth'] = df['alt_businessgrowth'].map({'Unlikely': 2, 'Very likely': 4, 'likely': 3, 'Very unlikely': 1})
df.head()
# Out:
#    gender  age  education  vsla_membership  business type  vsla_dependency  \
# 0       1    2          4                1              6                1
# 1       1    2          4                2              5                3
# 2       2    2          4                2              6                1
# 3       1    1          3                2              1                4
# 4       1    2          4                3              3                4
#
#    loan_satisfaction  saving  loan  financial_training  emergency_loan  \
# 0                  1     1.0   2.0                 2.0             2.0
# 1                  2     2.0   2.0                 3.0             1.0
# 2                  2     3.0   1.0                 1.0             1.0
# 3                  3     4.0   4.0                 4.0             4.0
# 4                  1     2.0   1.0                 3.0             1.0
#
#    memmbers_trading  intergroup_trade  vsa_business_network  alt_currency  \
# ...

# %%
print(df['alt_tradepromotion'].unique())
# Out:
# ['Unlikely' 'Very likely' 'likely' 'Very unlikely' 'Unlikely;Very likely'
#  'likely;Very likely' 'Very unlikely;Unlikely;likely;Very likely'
#  'Very unlikely;Very likely']

# %%
df['alt_tradepromotion'] = df['alt_tradepromotion'].map({'Unlikely': 2, 'Very likely': 4, 'likely': 3, 'Very unlikely': 1})
df.head()
# Out:
#    gender  age  education  vsla_membership  business type  vsla_dependency  \
# 0       1    2          4                1              6                1
# 1       1    2          4                2              5                3
# 2       2    2          4                2              6                1
# 3       1    1          3                2              1                4
# 4       1    2          4                3              3                4
#
#    loan_satisfaction  saving  loan  financial_training  emergency_loan  \
# 0                  1     1.0   2.0                 2.0             2.0
# 1                  2     2.0   2.0                 3.0             1.0
# 2                  2     3.0   1.0                 1.0             1.0
# 3                  3     4.0   4.0                 4.0             4.0
# 4                  1     2.0   1.0                 3.0             1.0
#
#    memmbers_trading  intergroup_trade  vsa_business_network  alt_currency  \
# ...

# %%
df.to_csv('my_data.csv', index=False)
print('CSV file saved in the same folder as my Jupiter Notebook')
# Out:
# CSV file saved in the same folder as my Jupiter Notebook
